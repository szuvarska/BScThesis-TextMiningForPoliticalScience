# %%
import pandas as pd
from Community_detection.community_graph_script import plot_community_graph

# %% [markdown]
# # Ukraine before

# %%
#df_ner_ukraine_before = pd.read_csv("../NER_and_ED/Results/Ukraine_before_with_NER.csv")
df_ner_ukraine_before = pd.read_csv("../Data/Sentances_df/sentences_ukraine_before.csv")
df_entities_ukraine_before = pd.read_csv("../NER_and_ED/Results/Ukraine_before_top_40_entities.csv")
#drop rows wehere word =  U B
df_entities_ukraine_before = df_entities_ukraine_before[~df_entities_ukraine_before.Word.isin(["U", "B", "N", "19", "G", "S"])].head(120)
df_ner_ukraine_before
# Out:
#      sentence_id  article_id  \
# 0        000-000           0
# 1        000-001           0
# 2        000-002           0
# 3        000-003           0
# 4        000-004           0
# ...          ...         ...
# 1350     049-002          49
# 1351     049-003          49
# 1352     049-004          49
# 1353     049-005          49
# 1354     049-006          49
#
#                                            article_text published_time  \
# 0     Russia President Vladimir Putin on Monday sign...     2022-02-23
# 1     Ukraine decided to recall its charge d'affairs...     2022-02-23
# 2     The sudden change in the Ukraine situation has...     2022-02-23
# 3     In this regard, China State Councilor and Fore...     2022-02-23
# 4     He said China once again called on all parties...     2022-02-23
# ...                                                 ...            ...
# 1350  US President Joe Biden said Tuesday that a Rus...     2022-02-18
# ...

# %%
suptitle = "Ukraine before conflict\n Co-occurrence in Same Sentence Relationship Graph"
title = "Nodes represent entities. Edges represent co-occurrence within the same sentence.\nNodes size indicates the node strength.\nEdge width indicates the frequency of co-occurrence. Spring Layout"

plot_community_graph(df_ner_ukraine_before, df_entities_ukraine_before, suptitle=suptitle, title=title, nodes_displayed= 25, layout="spring", edge="std")
# Out:
# 1355it [00:00, 43347.43it/s]
# <module 'matplotlib.pyplot' from 'C:\\Users\\lukas\\AppData\\Local\\Programs\\Python\\Python311\\Lib\\site-packages\\matplotlib\\pyplot.py'>

# %% [markdown]
# # Ukraine after

# %%
#df_ner_ukraine_after = pd.read_csv("../NER and ED/Results/Ukraine_after_with_NER.csv")
df_ner_ukraine_after = pd.read_csv("../Data/Sentances_df/sentences_ukraine_before.csv")
df_entities_ukraine_after = pd.read_csv("../NER_and_ED/Results/Ukraine_after_top_40_entities.csv")
#drop rows wehere word =  U B
df_entities_ukraine_after = df_entities_ukraine_after[~df_entities_ukraine_after.Word.isin(["U", "B", "N", "19", "G", "S", "C", "one"])]
df_ner_ukraine_after
# Out:
#      sentence_id  article_id  \
# 0        000-000           0
# 1        000-001           0
# 2        000-002           0
# 3        000-003           0
# 4        000-004           0
# ...          ...         ...
# 1350     049-002          49
# 1351     049-003          49
# 1352     049-004          49
# 1353     049-005          49
# 1354     049-006          49
#
#                                            article_text published_time  \
# 0     Russia President Vladimir Putin on Monday sign...     2022-02-23
# 1     Ukraine decided to recall its charge d'affairs...     2022-02-23
# 2     The sudden change in the Ukraine situation has...     2022-02-23
# 3     In this regard, China State Councilor and Fore...     2022-02-23
# 4     He said China once again called on all parties...     2022-02-23
# ...                                                 ...            ...
# 1350  US President Joe Biden said Tuesday that a Rus...     2022-02-18
# ...

# %%
suptitle = "Ukraine during conflict\n Co-occurrence in Same Sentence Relationship Graph"
title = "Nodes represent entities. Edges represent co-occurrence within the same sentence.\nNodes size indicates the node strength.\nEdge width indicates the frequency of co-occurrence. Spring Layout"

plot_community_graph(df_ner_ukraine_after, df_entities_ukraine_after, suptitle=suptitle, title=title, nodes_displayed= 25, layout="spring", edge="std")
# Out:
# 1355it [00:00, 28900.49it/s]
# <module 'matplotlib.pyplot' from 'C:\\Users\\lukas\\AppData\\Local\\Programs\\Python\\Python311\\Lib\\site-packages\\matplotlib\\pyplot.py'>

# %% [markdown]
# # Gaza after

# %%
df_ner_gaza_after = pd.read_csv("../Data/Sentances_df/sentences_gaza_after.csv")
df_entities_gaza_after = pd.read_csv("../NER_and_ED/Results/Gaza_after_top_40_entities.csv")
#drop rows wehere word =  U B
df_entities_gaza_after = df_entities_gaza_after[~df_entities_gaza_after.Word.isin(["U", "B", "N", "19", "G", "S", "Ho", "pro", "anti"])]
df_entities_gaza_after
# Out:
#     Entity Type             Word  Count
# 0           LOC           Israel   1653
# 1           LOC            China   1479
# 2           LOC               US   1405
# 3           LOC             Gaza   1226
# 4           LOC        Palestine    796
# ..          ...              ...    ...
# 155         PER         Cui Heng      9
# 156         PER  Henry Kissinger      9
# 157         PER     Zhang Youxia      9
# 158         PER        Nong Rong      9
# 159         PER               Al      8
#
# [157 rows x 3 columns]

# %%
suptitle = "Gaza during conflict\n Co-occurrence in Same Sentence Relationship Graph"
title = "Nodes represent entities. Edges represent co-occurrence within the same sentence.\nNodes size indicates the node strength.\nEdge width indicates the frequency of co-occurrence. Spring Layout"

plot_community_graph(df_ner_gaza_after, df_entities_gaza_after, suptitle=suptitle, title=title, nodes_displayed= 25, layout="spring", edge="std")
# Out:
# 789it [00:00, 50590.95it/s]
# <module 'matplotlib.pyplot' from 'C:\\Users\\lukas\\AppData\\Local\\Programs\\Python\\Python311\\Lib\\site-packages\\matplotlib\\pyplot.py'>

# %%
df_ner_gaza_before = pd.read_csv("../Data/Sentances_df/sentences_gaza_before.csv")
df_entities_gaza_before = pd.read_csv("../NER_and_ED/Results/Gaza_before_top_40_entities.csv")
#drop rows wehere word =  U B
df_entities_gaza_before = df_entities_gaza_before[~df_entities_gaza_before.Word.isin(["U", "B", "N", "19", "G", "S", "Ho", "pro", "anti", "E", "com" ])]
df_entities_gaza_before
# Out:
#     Entity Type                   Word  Count
# 0          MISC  Mid - Autumn Festival    350
# 1          MISC                    Mid    280
# 2          MISC        Autumn Festival    280
# 3          MISC                  Greek    210
# 4          MISC                F - 35B    140
# ..          ...                    ...    ...
# 155         PER              Zhang Kai      4
# 156         PER              Zhou Rong      3
# 157         PER   Abdelmadjid Tebboune      3
# 158         PER                 Xi Jin      3
# 159         PER              Ami Eshed      3
#
# [158 rows x 3 columns]

# %%
suptitle = "Gaza before conflict\n Co-occurrence in Same Sentence Relationship Graph"
title = "Nodes represent entities. Edges represent co-occurrence within the same sentence.\nNodes size indicates the node strength.\nEdge width indicates the frequency of co-occurrence. Spring Layout"

plot_community_graph(df_ner_gaza_before, df_entities_gaza_before, suptitle=suptitle, title=title, nodes_displayed= 25, layout="spring", edge="std")
# Out:
# 789it [00:00, 25319.67it/s]
# <module 'matplotlib.pyplot' from 'C:\\Users\\lukas\\AppData\\Local\\Programs\\Python\\Python311\\Lib\\site-packages\\matplotlib\\pyplot.py'>
