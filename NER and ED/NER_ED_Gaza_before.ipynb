# %%
from NER_ED_script import perform_ner, calculate_entity_distribution, find_most_common_entity_types, find_most_common_entities_per_type
# Out:
# 2024-11-16 21:53:34.139682: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-11-16 21:53:34.982913: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
file_name = "../Data/gaza_textcontain_before_new_preprocessed.csv"
dict_name = "dict_gaza.csv"
ner_file = "Results/Gaza_before_with_NER.csv"
dataset_name = "Gaza before conflict"
entities_file = "Results/Gaza_before_top_40_entities.csv"

# %%
df = perform_ner(file_name, dict_name, ner_file)
# Out:
# Some weights of the model checkpoint at dbmdz/bert-large-cased-finetuned-conll03-english were not used when initializing BertForTokenClassification: ['bert.pooler.dense.bias', 'bert.pooler.dense.weight']
# - This IS expected if you are initializing BertForTokenClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForTokenClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).

# %%
calculate_entity_distribution(df, dataset_name)
# Out:
#    Unnamed: 0                                      article_title  \
# 0           0  Various celebrations held across world to cele...
# 1           1  First Saudi ambassador to Palestine arrives in...
# 2           2  China releases a white paper on its proposals ...
# 3           3               Kaparot ceremony in Tel Aviv, Israel
# 4           4  1,100 Gazan kidney patients facing drug shorta...
#
#                author published_time  \
# 0              Xinhua     2023-09-29
# 1              Xinhua     2023-09-27
# 2  GT staff reporters     2023-09-26
# 3              Xinhua     2023-09-22
# 4              Xinhua     2023-09-21
#
#                                         article_text article_category_one  \
# 0   Musicians perform during a Mid-Autumn Festiva...                PHOTO
# 1   \n\nSaudi Arabia ambassador to Palestine Naif...                PHOTO
# 2   The China government released a white paper o...                CHINA
# 3   \n\nUltra Orthodox Jews perform the Kaparot c...                PHOTO
# 4   \n\nA young Palestine patient receives treatm...                PHOTO
#
#   article_category_two                                picture_description  \
# 0                WORLD  Australian youths sing Chinese version of the ...
# 1                WORLD  Saudi ambassador to Palestine Naif bin Bandar ...
# 2             POLITICS                               Photo: Li Xuanmin/GT
# 3                WORLD  Ultra Orthodox Jews perform the Kaparot ceremo...
# 4                WORLD  A young Palestinian patient receives treatment...
#
#                author_title        author_description  \
# 0  Author details not found  Author details not found
# 1  Author details not found  Author details not found
# 2  Author details not found  Author details not found
# 3  Author details not found  Author details not found
# 4  Author details not found  Author details not found
#
#                                                  NER  Named_Entity_Words  \
# 0  {'Mid': ('MISC', 8), 'Autumn Festival': ('MISC...                  52
# 1  {'Saudi Arabia': ('LOC', 9), 'Palestine': ('LO...                  66
# 2  {'China': ('LOC', 8), 'Global Community of S':...                  11
# 3  {'Ultra Orthodox Jews': ('MISC', 1), 'Kaparot'...                  15
# 4  {'Palestine': ('LOC', 3), 'Gaza': ('LOC', 6), ...                  21
#
#    total_words  Non_Entity_Words
# 0         1245              1193
# 1         2263              2197
# 2         6679              6668
# 3          506               491
# 4         1464              1443
# Total Words:  1526944
# Total Named Entity Words:  16273
# Total Non-Named Entity Words:  1510671
# Average number of words per article/length: 3201.140461215933
# Percentage of words in articles that are named entities: 1.0657234319005804

# %%
find_most_common_entity_types(df, dataset_name)

# %%
find_most_common_entities_per_type(df, dataset_name, entities_file)
# Out:
# Top words by entity type have been saved to Results/Gaza_before_top_40_entities.csv.
