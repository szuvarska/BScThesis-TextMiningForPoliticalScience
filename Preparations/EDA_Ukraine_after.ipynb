# %%
import pandas as pd
import EDA_scritpt as EDA
import Preprocessing_script as Preprocessing
# Out:
# {'i', 'Am', 'Hasn', "wasn't", "couldn't", 'Any', 'how', 'once', 'Theirs', 'she', 'haven', 'Shan', 'is', 'Will', 'Weren', 'such', 'Again', 'about', 'Doesn', 'Re', 'if', 'Yourself', "she's", 'Same', 'these', 'then', 'An', 'In', 'Over', 'with', 'under', 'Don', 'Its', "that'll", 'Those', 'Ain', 'Hadn', 're', 'off', "should've", 'Where', 'They', 'above', 'here', 'weren', 'Myself', 'until', 'Were', 'their', 'Ve', 'theirs', "Doesn't", 'Is', 'they', 'M', 'him', 'About', "Didn't", 'won', 'Himself', "Shan't", 'Itself', 'When', 'up', 'At', 'so', 'Needn', 'below', 'He', 'Which', 'any', "It's", 'Do', 'Has', 'Herself', 'Because', 'Very', 'a', 't', 'wasn', 'yours', 'Only', 'Above', 'Her', 'Y', 'Against', 'yourselves', 'm', 'aren', "isn't", 'Themselves', 'Not', 'that', 'whom', 'what', "Wouldn't", 'Both', 'Be', 'nor', "you'll", 'You', 'wouldn', 'very', 'Their', 'Why', "you're", 'couldn', 'Having', 'd', 'mightn', 'Few', 'So', 'he', "Wasn't", 'doesn', "That'll", 'Down', 'no', 'it', 'No', 'It', "mightn'
# ...

# %% [markdown]
# # UKRAINE AFTER

# %%
articles = pd.read_csv('../Data/ukraine_textcontain_after_new.csv')
authors = pd.read_csv('../Data/ukraine_textcontain_after_new_authors.csv')

# %%
articles
# Out:
#                                          article_title                 author  \
# 0    US can no longer be perfunctory toward Guterre...        By Global Times
# 1    Healthy and stable China-S.Korea ties depend o...       By Wang Junsheng
# 2    China’s power in the world, economically and p...        By Global Times
# 3    Europe faces ‘coldest’ winter as energy crisis...            By Qi Xijia
# 4    Severe drought in Europe ‘further expanding an...                 By AFP
# ..                                                 ...                    ...
# 485  US policy of ‘technological apartheid’ could l...       By William Jones
# 486  US behind global grain crises: Chinese FM spok...        By Global Times
# 487  ‘No longer US’ backyard,’ Latin America sends ...  By GT staff reporters
# 488  Chinese envoy warns against providing weapons ...              By Xinhua
# 489  Ukraine, Moldova agree to facilitate border cr...              By Xinhua
#
# ...

# %%
articles = Preprocessing.celan_articles(articles)
df = Preprocessing.merge_articles_authors(articles, authors)

# %%
df
# Out:
#                                          article_title              author  \
# 0    US can no longer be perfunctory toward Guterre...        Global Times
# 1    Healthy and stable China-S.Korea ties depend o...       Wang Junsheng
# 2    China’s power in the world, economically and p...        Global Times
# 3    Europe faces ‘coldest’ winter as energy crisis...            Qi Xijia
# 4    Severe drought in Europe ‘further expanding an...                 AFP
# ..                                                 ...                 ...
# 485  US policy of ‘technological apartheid’ could l...       William Jones
# 486  US behind global grain crises: Chinese FM spok...        Global Times
# 487  ‘No longer US’ backyard,’ Latin America sends ...  GT staff reporters
# 488  Chinese envoy warns against providing weapons ...              Xinhua
# 489  Ukraine, Moldova agree to facilitate border cr...              Xinhua
#
# ...

# %%
df, df_pos = EDA.perpare_df_for_eda(df)
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\lukas\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!

# %%
EDA.plot_word_cout_distribution(df, "Ukraine during war")

# %%
EDA.sentance_count_distribution(df, "Ukraine during war")

# %%
EDA.plot_top_N_common_words(df, "Ukraine during war", 100)

# %%
EDA.plot_top_N_common_pos(df_pos, "Ukraine during war")

# %%
EDA.plot_pos_wordclouds(df, "Ukraine during war", 100)
