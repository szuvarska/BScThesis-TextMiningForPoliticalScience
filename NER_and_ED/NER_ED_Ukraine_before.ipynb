# %%
from NER_ED_script import perform_ner, calculate_entity_distribution, find_most_common_entity_types, find_most_common_entities_per_type
# Out:
# 2024-11-16 22:30:31.525591: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-11-16 22:30:32.772238: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
file_name = "../Data/ukraine_textcontain_before_new_preprocessed.csv"
dict_name = "dict_ukraine.csv"
ner_file = "Results/Ukraine_before_with_NER.csv"
dataset_name = "Ukraine before conflict"
entities_file = "Results/Ukraine_before_top_40_entities.csv"

# %%
df = perform_ner(file_name, dict_name, ner_file)
# Out:
# Some weights of the model checkpoint at dbmdz/bert-large-cased-finetuned-conll03-english were not used when initializing BertForTokenClassification: ['bert.pooler.dense.bias', 'bert.pooler.dense.weight']
# - This IS expected if you are initializing BertForTokenClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForTokenClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).

# %%
calculate_entity_distribution(df, dataset_name)
# Out:
#    Unnamed: 0                                      article_title  \
# 0           0  All sides should give Russia, Ukraine some spa...
# 1           1  Ukrainian president expects no conflict with R...
# 2           2  British PM announces sanctions against Russia ...
# 3           3  NATO chief urges Russia to choose diplomacy in...
# 4           4  EU agrees Russia sanctions package, warns of f...
#
#          author published_time  \
# 0  Global Times     2022-02-23
# 1        Xinhua     2022-02-23
# 2        Xinhua     2022-02-23
# 3        Xinhua     2022-02-23
# 4        Xinhua     2022-02-23
#
#                                         article_text article_category_one  \
# 0  Russia President Vladimir Putin on Monday sign...              OPINION
# 1   Ukraine President Volodymyr Zelensky said on ...                WORLD
# 2   UK Prime Minister Boris Johnson announced on ...                WORLD
# 3   The chief of the NATO (NATO) has urged Russia...                WORLD
# 4   The EU (EU) is ready to take further action a...                WORLD
#
#   article_category_two                                picture_description  \
# 0            EDITORIAL  United Nations Security Council meets after Ru...
# 1               EUROPE  Ukrainian President Volodymyr Zelensky attends...
# 2               EUROPE    British Prime Minister Boris Johnson Photo: VCG
# 3               EUROPE  NATO Secretary General Jens Stoltenberg speaks...
# 4               EUROPE  European Commission President Ursula von der L...
#
#                author_title        author_description  \
# 0  Author details not found  Author details not found
# 1  Author details not found  Author details not found
# 2  Author details not found  Author details not found
# 3  Author details not found  Author details not found
# 4  Author details not found  Author details not found
#
#                                                  NER  Named_Entity_Words  \
# 0  {'Russia': ('LOC', 14), 'Lugansk': ('LOC', 1),...                  44
# 1  {'Ukraine': ('LOC', 3), 'Russia': ('LOC', 5), ...                  22
# 2  {'UK': ('LOC', 5), 'Russia': ('LOC', 6), 'Ukra...                  27
# 3  {'NATO': ('ORG', 8), 'EU': ('ORG', 3), 'NATO -...                  41
# 4  {'EU': ('ORG', 10), 'EU Commission': ('ORG', 1...                  58
#
#    total_words  Non_Entity_Words
# 0         4483              4439
# 1          870               848
# 2         1222              1195
# 3         1521              1480
# 4         3233              3175
# Total Words:  1664176
# Total Named Entity Words:  20170
# Total Non-Named Entity Words:  1644006
# Average number of words per article/length: 3510.9198312236285
# Percentage of words in articles that are named entities: 1.2120112295814867

# %%
find_most_common_entity_types(df, dataset_name)

# %%
find_most_common_entities_per_type(df, dataset_name, entities_file)
# Out:
# Top words by entity type have been saved to Results/Ukraine_before_top_40_entities.csv.
